# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df_file_csv = pd.read_csv('./data/CalificacionesTXT.csv')
# df_file_csv.head()
# # df_file_csv.info()
# # df_file_csv.describe()

# df_column = 'Programa'

# df_file_csv[df_column].value_counts()


# column_filter = df_file_csv[(df_file_csv[df_column] == 'Contabilidad') & (df_file_csv['Genero'] == 'Masculino') & (df_file_csv['Matematicas'].str.replace(',', '.').astype(float) > 4)]
# column_filter

# %%
df_file_csv = pd.read_csv('./data/netflix_titles.csv')
df_file_csv

# TODO: Adjuntar por cantidad de valores de alguna columna

# Filtrar por películas hechas en United States y que sean del año mayor al 2010 y que tengan comedia en su género

# df_column = 'country'
# df_column_year = 'release_year'


# column_filter = df_file_csv[(df_file_csv[df_column] == 'India') & (df_file_csv[df_column_year] > 2010) & (df_file_csv['listed_in'].str.contains('Comedies'))]
# column_filter
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data_sin_duplicados = df_file_csv.drop_duplicates()
data_sin_duplicados

# %%
data_sin_null = data_sin_duplicados.dropna()
data_sin_null

# %%
llenar_null = data_sin_duplicados.fillna('Sin información')
llenar_null

# %%
print(data_sin_null.plot())

# %%
# Importar Calificaciones.xlsx desde local,
# URL Github (https://github.com/rubisabel00/ciencias-de-datos-Sena/blob/main/DocumentosNB03/clientes.csv) y 
# URL Drive (https://docs.google.com/spreadsheets/d/1ESAazOFyKEDpAHk1iEBE42KbuSddaEje/edit?usp=sharing&ouid=102864593123372232032&rtpof=true&sd=true)

df_file_xlsx = pd.read_excel('./data/Calificaciones.xlsx')
df_file_xlsx.head()
# Out:
#    ITEM NOMBRES  APELLIDOS        Programa     Genero  Matematicas  Español  \
# 0     1    Juan     García    Contabilidad  Masculino         1.66     2.19
# 1     2   María      Pérez        Mercadeo   Femenino         3.21     2.54
# 2     3   Pedro  Fernández        Sistemas  Masculino         3.10     3.11
# 3     4     Ana    Sánchez  Administracion   Femenino          NaN     2.50
# 4     5    Luis   González           Salud  Masculino         2.91     2.59
#
#    Ciencias  Idiomas
# 0      3.56     2.58
# 1      1.98     3.76
# 2      2.62     2.42
# 3      3.66     1.93
# 4      2.45      NaN
